# %%
import os
import keras
import random
# Out:
# 2022-06-29 09:55:41.412815: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-06-29 09:55:41.417598: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-29 09:55:41.417612: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
classes = {0: "falaise" , 1: "batiment", 2:"route",3:"pierrier",4:"verger",
            5:"champ",6:"prairie",7:"foret",8:"foret_claire",9:"buisson",10:"eau"}

# %%
import numpy as np
import tensorflow as tf
from keras import backend as K
import matplotlib.pyplot as plt
import segmentation_models as sm
from utils import visualize, freeze_session
from data_loader import Dataset, Dataloader
from keras.backend import set_session
from augmentation import *
# Out:
# Segmentation Models: using `keras` framework.

# %%
# Tensorflow session
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True  # dynamically grow the memory used on the GPU
config.log_device_placement = False  # to log device placement (on which device the operation ran)
sess = tf.compat.v1.Session(config=config)
set_session(sess)  # set this TensorFlow session as the default session for Keras

train_dir = "Synthese/Train/"
test_dir = "Synthese/Valid/"
result_dir = "Synthese2/Result/"
image_size = 512
image_channels = 3
padding_size = 800
n_classes = 11

# model parameters
BACKBONE = 'efficientnetb3'
BATCH_SIZE = 8
LR = 0.001
EPOCHS = 100
activation ='softmax'
# Out:
# 2022-06-29 09:56:01.813448: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
if not os.path.exists(result_dir):
    os.mkdir(result_dir)
    
x_train_dir = os.path.join(train_dir, 'images')
y_train_dir = os.path.join(train_dir, 'masks')
x_valid_dir = os.path.join(test_dir, 'images')
y_valid_dir = os.path.join(test_dir, 'masks')


# define network parameters 
preprocess_input = sm.get_preprocessing(BACKBONE)

# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=n_classes, 
    augmentation=False,
    preprocessing=get_preprocessing(preprocess_input),
    #preprocessing=False,
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=n_classes, 
    augmentation=False,
    preprocessing=get_preprocessing(preprocess_input),
    #preprocessing=False,
)

# %%
#create model
model = sm.Unet(BACKBONE,classes=n_classes, activation=activation)

# define optomizer
optim = keras.optimizers.Adam(LR)

# Segmentation models losses can be combined together by '+' and scaled by integer or float factor
dice_loss = sm.losses.DiceLoss(class_weights=np.ones(n_classes)) 
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1 * focal_loss)

metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

# compile keras model with defined optimozer, loss and metrics
model.compile(optim, total_loss, metrics)
# Out:
# 2022-06-29 09:56:11.734799: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
BATCH_SIZE = 8
#Dataloaders
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloader(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, image_size, image_size, image_channels)
assert train_dataloader[0][1].shape == (BATCH_SIZE, image_size, image_size, n_classes)

# %%
# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint(os.path.join(result_dir,'best_model.h5'), save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]

# train model
history = model.fit(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)
# Out:
# Epoch 1/100
# 51/51 [==============================] - 442s 8s/step - loss: 0.7166 - iou_score: 0.3203 - f1-score: 0.3851 - val_loss: 0.9006 - val_iou_score: 0.4405 - val_f1-score: 0.4708 - lr: 0.0010
# Epoch 2/100
# 51/51 [==============================] - 414s 8s/step - loss: 0.4651 - iou_score: 0.5549 - f1-score: 0.6261 - val_loss: 0.8545 - val_iou_score: 0.4662 - val_f1-score: 0.5003 - lr: 0.0010
# Epoch 3/100
# 51/51 [==============================] - 403s 8s/step - loss: 0.3838 - iou_score: 0.5985 - f1-score: 0.6601 - val_loss: 0.7849 - val_iou_score: 0.5200 - val_f1-score: 0.5530 - lr: 0.0010
# Epoch 4/100
# 51/51 [==============================] - 404s 8s/step - loss: 0.3363 - iou_score: 0.6362 - f1-score: 0.7081 - val_loss: 0.7851 - val_iou_score: 0.4966 - val_f1-score: 0.5315 - lr: 0.0010
# Epoch 5/100
# 51/51 [==============================] - 407s 8s/step - loss: 0.2930 - iou_score: 0.6826 - f1-score: 0.7511 - val_loss: 0.7092 - val_iou_score: 0.5530 - val_f1-score: 0.5791 - lr: 0.0010
# Epoch 6/100
# 51/51 [==============================] - 417s 8s/step - loss: 0.2591 - iou_score: 0.7079 - f1-score: 0.7685 - val_loss: 0.7562 - val_iou_score: 0.5422 - val_f1-score: 0.5720 - lr: 0.0010
# Epoch 7/100
# 51/51 [==============================] - 401s 8s/step - loss: 0.2338 - iou_score: 0.7374 - f1-score: 0.7915 - val_loss: 0.6946 - val_iou_score: 0.5988 - val_f1-score: 0.6207 - lr: 0.0010
# Epoch 8/100
# 51/51 [==============================] - 402s 8s/step - loss: 0.2222 - iou_score: 0.7529 - f1-score: 0.8031 - val_loss: 0.6969 - val_iou_score: 0.5912 - val_f1-score: 0.6153 - lr: 0.0010
# Epoch 9/100
# 51/51 [==============================] - 404s 8s/step - loss: 0.2113 - iou_score: 0.7633 - f1-score: 0.8100 - val_loss: 0.6804 - val_iou_score: 0.6059 - val_f1-score: 0.6277 - lr: 0.0010
# Epoch 10/100
# 51/51 [==============================] - 403s 8s/step - loss: 0.2018 - iou_score: 0.7702 - f1-score: 0.8138 - val_loss: 0.6845 - val_iou_score: 0.6246 - val_f1-score: 0.6458 - lr: 0.0010
# Epoch 11/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1851 - iou_score: 0.7936 - f1-score: 0.8323 - val_loss: 0.6824 - val_iou_score: 0.6660 - val_f1-score: 0.6829 - lr: 0.0010
# Epoch 12/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.1933 - iou_score: 0.7787 - f1-score: 0.8179 - val_loss: 0.7431 - val_iou_score: 0.5371 - val_f1-score: 0.5649 - lr: 0.0010
# Epoch 13/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.2191 - iou_score: 0.7472 - f1-score: 0.7968 - val_loss: 0.6944 - val_iou_score: 0.5927 - val_f1-score: 0.6121 - lr: 0.0010
# Epoch 14/100
# 51/51 [==============================] - 401s 8s/step - loss: 0.1890 - iou_score: 0.7822 - f1-score: 0.8238 - val_loss: 0.6900 - val_iou_score: 0.6183 - val_f1-score: 0.6369 - lr: 0.0010
# Epoch 15/100
# 51/51 [==============================] - 403s 8s/step - loss: 0.1803 - iou_score: 0.7971 - f1-score: 0.8357 - val_loss: 0.6862 - val_iou_score: 0.6675 - val_f1-score: 0.6886 - lr: 0.0010
# Epoch 16/100
# 51/51 [==============================] - 403s 8s/step - loss: 0.1716 - iou_score: 0.8050 - f1-score: 0.8396 - val_loss: 0.6753 - val_iou_score: 0.6943 - val_f1-score: 0.7082 - lr: 0.0010
# Epoch 17/100
# 51/51 [==============================] - 401s 8s/step - loss: 0.1604 - iou_score: 0.8173 - f1-score: 0.8468 - val_loss: 0.6620 - val_iou_score: 0.6980 - val_f1-score: 0.7117 - lr: 0.0010
# Epoch 18/100
# 51/51 [==============================] - 400s 8s/step - loss: 0.1541 - iou_score: 0.8327 - f1-score: 0.8599 - val_loss: 0.6630 - val_iou_score: 0.6932 - val_f1-score: 0.7077 - lr: 0.0010
# Epoch 19/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.1505 - iou_score: 0.8399 - f1-score: 0.8664 - val_loss: 0.6557 - val_iou_score: 0.6954 - val_f1-score: 0.7112 - lr: 0.0010
# Epoch 20/100
# 51/51 [==============================] - 399s 8s/step - loss: 0.1460 - iou_score: 0.8372 - f1-score: 0.8617 - val_loss: 0.6604 - val_iou_score: 0.6936 - val_f1-score: 0.7120 - lr: 0.0010
# Epoch 21/100
# 51/51 [==============================] - 400s 8s/step - loss: 0.1526 - iou_score: 0.8322 - f1-score: 0.8610 - val_loss: 0.6720 - val_iou_score: 0.6824 - val_f1-score: 0.7002 - lr: 0.0010
# Epoch 22/100
# 51/51 [==============================] - 400s 8s/step - loss: 0.1529 - iou_score: 0.8302 - f1-score: 0.8588 - val_loss: 0.6603 - val_iou_score: 0.6793 - val_f1-score: 0.6975 - lr: 0.0010
# Epoch 23/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1537 - iou_score: 0.8231 - f1-score: 0.8552 - val_loss: 0.6678 - val_iou_score: 0.6483 - val_f1-score: 0.6696 - lr: 0.0010
# Epoch 24/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.1501 - iou_score: 0.8264 - f1-score: 0.8561 - val_loss: 0.6474 - val_iou_score: 0.7107 - val_f1-score: 0.7289 - lr: 0.0010
# Epoch 25/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1447 - iou_score: 0.8366 - f1-score: 0.8649 - val_loss: 0.6404 - val_iou_score: 0.7082 - val_f1-score: 0.7276 - lr: 0.0010
# Epoch 26/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1555 - iou_score: 0.8273 - f1-score: 0.8606 - val_loss: 0.6598 - val_iou_score: 0.6721 - val_f1-score: 0.6920 - lr: 0.0010
# Epoch 27/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1524 - iou_score: 0.8256 - f1-score: 0.8588 - val_loss: 0.6829 - val_iou_score: 0.6520 - val_f1-score: 0.6795 - lr: 0.0010
# Epoch 28/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1483 - iou_score: 0.8329 - f1-score: 0.8657 - val_loss: 0.6592 - val_iou_score: 0.6457 - val_f1-score: 0.6691 - lr: 0.0010
# Epoch 29/100
# 51/51 [==============================] - 411s 8s/step - loss: 0.1615 - iou_score: 0.8165 - f1-score: 0.8540 - val_loss: 0.6429 - val_iou_score: 0.6851 - val_f1-score: 0.7071 - lr: 0.0010
# Epoch 30/100
# 51/51 [==============================] - 405s 8s/step - loss: 0.1408 - iou_score: 0.8383 - f1-score: 0.8695 - val_loss: 0.6406 - val_iou_score: 0.7089 - val_f1-score: 0.7330 - lr: 0.0010
# Epoch 31/100
# 51/51 [==============================] - 410s 8s/step - loss: 0.1310 - iou_score: 0.8587 - f1-score: 0.8847 - val_loss: 0.6391 - val_iou_score: 0.7124 - val_f1-score: 0.7319 - lr: 0.0010
# Epoch 32/100
# 51/51 [==============================] - 411s 8s/step - loss: 0.1264 - iou_score: 0.8611 - f1-score: 0.8854 - val_loss: 0.6319 - val_iou_score: 0.7189 - val_f1-score: 0.7391 - lr: 0.0010
# Epoch 33/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1243 - iou_score: 0.8619 - f1-score: 0.8854 - val_loss: 0.6367 - val_iou_score: 0.7253 - val_f1-score: 0.7451 - lr: 0.0010
# Epoch 34/100
# 51/51 [==============================] - 390s 8s/step - loss: 0.1226 - iou_score: 0.8692 - f1-score: 0.8921 - val_loss: 0.6264 - val_iou_score: 0.7342 - val_f1-score: 0.7552 - lr: 0.0010
# Epoch 35/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1202 - iou_score: 0.8670 - f1-score: 0.8889 - val_loss: 0.6243 - val_iou_score: 0.7418 - val_f1-score: 0.7622 - lr: 0.0010
# Epoch 36/100
# 51/51 [==============================] - 406s 8s/step - loss: 0.1189 - iou_score: 0.8667 - f1-score: 0.8883 - val_loss: 0.6252 - val_iou_score: 0.7291 - val_f1-score: 0.7490 - lr: 0.0010
# Epoch 37/100
# 51/51 [==============================] - 417s 8s/step - loss: 0.1176 - iou_score: 0.8717 - f1-score: 0.8930 - val_loss: 0.6225 - val_iou_score: 0.7309 - val_f1-score: 0.7519 - lr: 0.0010
# Epoch 38/100
# 51/51 [==============================] - 411s 8s/step - loss: 0.1172 - iou_score: 0.8702 - f1-score: 0.8917 - val_loss: 0.6255 - val_iou_score: 0.7200 - val_f1-score: 0.7403 - lr: 0.0010
# Epoch 39/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1163 - iou_score: 0.8714 - f1-score: 0.8925 - val_loss: 0.6181 - val_iou_score: 0.7269 - val_f1-score: 0.7495 - lr: 0.0010
# Epoch 40/100
# 51/51 [==============================] - 390s 8s/step - loss: 0.1152 - iou_score: 0.8759 - f1-score: 0.8971 - val_loss: 0.6204 - val_iou_score: 0.7251 - val_f1-score: 0.7472 - lr: 0.0010
# Epoch 41/100
# 51/51 [==============================] - 391s 8s/step - loss: 0.1251 - iou_score: 0.8662 - f1-score: 0.8917 - val_loss: 0.6610 - val_iou_score: 0.6554 - val_f1-score: 0.6830 - lr: 0.0010
# Epoch 42/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1392 - iou_score: 0.8431 - f1-score: 0.8760 - val_loss: 0.6373 - val_iou_score: 0.6250 - val_f1-score: 0.6505 - lr: 0.0010
# Epoch 43/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1666 - iou_score: 0.8002 - f1-score: 0.8427 - val_loss: 0.6705 - val_iou_score: 0.6141 - val_f1-score: 0.6443 - lr: 0.0010
# Epoch 44/100
# 51/51 [==============================] - 391s 8s/step - loss: 0.1525 - iou_score: 0.8201 - f1-score: 0.8573 - val_loss: 0.6429 - val_iou_score: 0.6779 - val_f1-score: 0.7041 - lr: 0.0010
# Epoch 45/100
# 51/51 [==============================] - 391s 8s/step - loss: 0.1261 - iou_score: 0.8661 - f1-score: 0.8928 - val_loss: 0.6268 - val_iou_score: 0.7363 - val_f1-score: 0.7596 - lr: 0.0010
# Epoch 46/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1218 - iou_score: 0.8716 - f1-score: 0.8967 - val_loss: 0.6154 - val_iou_score: 0.7298 - val_f1-score: 0.7533 - lr: 0.0010
# Epoch 47/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1166 - iou_score: 0.8726 - f1-score: 0.8959 - val_loss: 0.6172 - val_iou_score: 0.7432 - val_f1-score: 0.7669 - lr: 0.0010
# Epoch 48/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.1220 - iou_score: 0.8677 - f1-score: 0.8931 - val_loss: 0.6294 - val_iou_score: 0.6834 - val_f1-score: 0.7105 - lr: 0.0010
# Epoch 49/100
# 51/51 [==============================] - 402s 8s/step - loss: 0.1265 - iou_score: 0.8612 - f1-score: 0.8892 - val_loss: 0.6239 - val_iou_score: 0.6703 - val_f1-score: 0.6945 - lr: 0.0010
# Epoch 50/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1288 - iou_score: 0.8505 - f1-score: 0.8785 - val_loss: 0.6462 - val_iou_score: 0.6702 - val_f1-score: 0.7024 - lr: 0.0010
# Epoch 51/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.1393 - iou_score: 0.8379 - f1-score: 0.8712 - val_loss: 0.6251 - val_iou_score: 0.7023 - val_f1-score: 0.7287 - lr: 0.0010
# Epoch 52/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1361 - iou_score: 0.8430 - f1-score: 0.8750 - val_loss: 0.6237 - val_iou_score: 0.6792 - val_f1-score: 0.7043 - lr: 0.0010
# Epoch 53/100
# 51/51 [==============================] - 389s 8s/step - loss: 0.1345 - iou_score: 0.8409 - f1-score: 0.8734 - val_loss: 0.6287 - val_iou_score: 0.7029 - val_f1-score: 0.7268 - lr: 0.0010
# Epoch 54/100
# 51/51 [==============================] - 391s 8s/step - loss: 0.1273 - iou_score: 0.8548 - f1-score: 0.8856 - val_loss: 0.6210 - val_iou_score: 0.7221 - val_f1-score: 0.7465 - lr: 0.0010
# Epoch 55/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1202 - iou_score: 0.8706 - f1-score: 0.8966 - val_loss: 0.6129 - val_iou_score: 0.7394 - val_f1-score: 0.7636 - lr: 0.0010
# Epoch 56/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1134 - iou_score: 0.8701 - f1-score: 0.8939 - val_loss: 0.6113 - val_iou_score: 0.7164 - val_f1-score: 0.7398 - lr: 0.0010
# Epoch 57/100
# 51/51 [==============================] - 393s 8s/step - loss: 0.1098 - iou_score: 0.8821 - f1-score: 0.9039 - val_loss: 0.6073 - val_iou_score: 0.7309 - val_f1-score: 0.7546 - lr: 0.0010
# Epoch 58/100
# 51/51 [==============================] - 389s 8s/step - loss: 0.1077 - iou_score: 0.8829 - f1-score: 0.9042 - val_loss: 0.6051 - val_iou_score: 0.7252 - val_f1-score: 0.7492 - lr: 0.0010
# Epoch 59/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1082 - iou_score: 0.8843 - f1-score: 0.9053 - val_loss: 0.6058 - val_iou_score: 0.7303 - val_f1-score: 0.7532 - lr: 0.0010
# Epoch 60/100
# 51/51 [==============================] - 400s 8s/step - loss: 0.1065 - iou_score: 0.8897 - f1-score: 0.9105 - val_loss: 0.6037 - val_iou_score: 0.7175 - val_f1-score: 0.7409 - lr: 0.0010
# Epoch 61/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1058 - iou_score: 0.8871 - f1-score: 0.9077 - val_loss: 0.5981 - val_iou_score: 0.7210 - val_f1-score: 0.7443 - lr: 0.0010
# Epoch 62/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1054 - iou_score: 0.8839 - f1-score: 0.9044 - val_loss: 0.6013 - val_iou_score: 0.7477 - val_f1-score: 0.7706 - lr: 0.0010
# Epoch 63/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1058 - iou_score: 0.8856 - f1-score: 0.9058 - val_loss: 0.6002 - val_iou_score: 0.7416 - val_f1-score: 0.7643 - lr: 0.0010
# Epoch 64/100
# 51/51 [==============================] - 409s 8s/step - loss: 0.1049 - iou_score: 0.8813 - f1-score: 0.9012 - val_loss: 0.5951 - val_iou_score: 0.7342 - val_f1-score: 0.7571 - lr: 0.0010
# Epoch 65/100
# 51/51 [==============================] - 407s 8s/step - loss: 0.1055 - iou_score: 0.8839 - f1-score: 0.9042 - val_loss: 0.6033 - val_iou_score: 0.7311 - val_f1-score: 0.7539 - lr: 0.0010
# Epoch 66/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1040 - iou_score: 0.8893 - f1-score: 0.9093 - val_loss: 0.5964 - val_iou_score: 0.7166 - val_f1-score: 0.7396 - lr: 0.0010
# Epoch 67/100
# 51/51 [==============================] - 389s 8s/step - loss: 0.1027 - iou_score: 0.8893 - f1-score: 0.9087 - val_loss: 0.5987 - val_iou_score: 0.7303 - val_f1-score: 0.7528 - lr: 0.0010
# Epoch 68/100
# 51/51 [==============================] - 390s 8s/step - loss: 0.1027 - iou_score: 0.8872 - f1-score: 0.9070 - val_loss: 0.5955 - val_iou_score: 0.7212 - val_f1-score: 0.7449 - lr: 0.0010
# Epoch 69/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1031 - iou_score: 0.8869 - f1-score: 0.9065 - val_loss: 0.5986 - val_iou_score: 0.7268 - val_f1-score: 0.7497 - lr: 0.0010
# Epoch 70/100
# 51/51 [==============================] - 407s 8s/step - loss: 0.1036 - iou_score: 0.8864 - f1-score: 0.9059 - val_loss: 0.5963 - val_iou_score: 0.7178 - val_f1-score: 0.7419 - lr: 0.0010
# Epoch 71/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.1010 - iou_score: 0.8875 - f1-score: 0.9067 - val_loss: 0.5955 - val_iou_score: 0.7216 - val_f1-score: 0.7455 - lr: 0.0010
# Epoch 72/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1013 - iou_score: 0.8872 - f1-score: 0.9064 - val_loss: 0.5950 - val_iou_score: 0.7086 - val_f1-score: 0.7317 - lr: 0.0010
# Epoch 73/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1004 - iou_score: 0.8953 - f1-score: 0.9143 - val_loss: 0.5935 - val_iou_score: 0.7188 - val_f1-score: 0.7430 - lr: 0.0010
# Epoch 74/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1010 - iou_score: 0.8896 - f1-score: 0.9085 - val_loss: 0.5927 - val_iou_score: 0.7350 - val_f1-score: 0.7599 - lr: 0.0010
# Epoch 75/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1004 - iou_score: 0.8885 - f1-score: 0.9073 - val_loss: 0.5888 - val_iou_score: 0.7393 - val_f1-score: 0.7634 - lr: 0.0010
# Epoch 76/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.0994 - iou_score: 0.8965 - f1-score: 0.9153 - val_loss: 0.5914 - val_iou_score: 0.7385 - val_f1-score: 0.7615 - lr: 0.0010
# Epoch 77/100
# 51/51 [==============================] - 398s 8s/step - loss: 0.0991 - iou_score: 0.8953 - f1-score: 0.9138 - val_loss: 0.5868 - val_iou_score: 0.7449 - val_f1-score: 0.7686 - lr: 0.0010
# Epoch 78/100
# 51/51 [==============================] - 399s 8s/step - loss: 0.0978 - iou_score: 0.8969 - f1-score: 0.9152 - val_loss: 0.5885 - val_iou_score: 0.7370 - val_f1-score: 0.7604 - lr: 0.0010
# Epoch 79/100
# 51/51 [==============================] - 399s 8s/step - loss: 0.0993 - iou_score: 0.8951 - f1-score: 0.9135 - val_loss: 0.5881 - val_iou_score: 0.7290 - val_f1-score: 0.7528 - lr: 0.0010
# Epoch 80/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1243 - iou_score: 0.8621 - f1-score: 0.8889 - val_loss: 0.6676 - val_iou_score: 0.5564 - val_f1-score: 0.5926 - lr: 0.0010
# Epoch 81/100
# 51/51 [==============================] - 392s 8s/step - loss: 0.1858 - iou_score: 0.7818 - f1-score: 0.8320 - val_loss: 0.7346 - val_iou_score: 0.4939 - val_f1-score: 0.5319 - lr: 0.0010
# Epoch 82/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1676 - iou_score: 0.7990 - f1-score: 0.8448 - val_loss: 0.9106 - val_iou_score: 0.4995 - val_f1-score: 0.5364 - lr: 0.0010
# Epoch 83/100
# 51/51 [==============================] - 397s 8s/step - loss: 0.1576 - iou_score: 0.8101 - f1-score: 0.8518 - val_loss: 0.6866 - val_iou_score: 0.5762 - val_f1-score: 0.6102 - lr: 0.0010
# Epoch 84/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1339 - iou_score: 0.8414 - f1-score: 0.8751 - val_loss: 0.6277 - val_iou_score: 0.6826 - val_f1-score: 0.7104 - lr: 0.0010
# Epoch 85/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1292 - iou_score: 0.8499 - f1-score: 0.8810 - val_loss: 0.6246 - val_iou_score: 0.6477 - val_f1-score: 0.6766 - lr: 0.0010
# Epoch 86/100
# 51/51 [==============================] - 395s 8s/step - loss: 0.1235 - iou_score: 0.8525 - f1-score: 0.8837 - val_loss: 0.6365 - val_iou_score: 0.6548 - val_f1-score: 0.6884 - lr: 0.0010
# Epoch 87/100
# 51/51 [==============================] - 399s 8s/step - loss: 0.1128 - iou_score: 0.8669 - f1-score: 0.8928 - val_loss: 0.6013 - val_iou_score: 0.7287 - val_f1-score: 0.7532 - lr: 0.0010
# Epoch 88/100
# 51/51 [==============================] - 407s 8s/step - loss: 0.1065 - iou_score: 0.8775 - f1-score: 0.9003 - val_loss: 0.5966 - val_iou_score: 0.7380 - val_f1-score: 0.7621 - lr: 1.0000e-04
# Epoch 89/100
# 51/51 [==============================] - 404s 8s/step - loss: 0.1042 - iou_score: 0.8842 - f1-score: 0.9061 - val_loss: 0.5943 - val_iou_score: 0.7384 - val_f1-score: 0.7625 - lr: 1.0000e-04
# Epoch 90/100
# 51/51 [==============================] - 415s 8s/step - loss: 0.1034 - iou_score: 0.8854 - f1-score: 0.9069 - val_loss: 0.5934 - val_iou_score: 0.7460 - val_f1-score: 0.7701 - lr: 1.0000e-04
# Epoch 91/100
# 51/51 [==============================] - 410s 8s/step - loss: 0.1033 - iou_score: 0.8818 - f1-score: 0.9033 - val_loss: 0.5924 - val_iou_score: 0.7459 - val_f1-score: 0.7701 - lr: 1.0000e-04
# Epoch 92/100
# 51/51 [==============================] - 401s 8s/step - loss: 0.1031 - iou_score: 0.8858 - f1-score: 0.9071 - val_loss: 0.5920 - val_iou_score: 0.7462 - val_f1-score: 0.7706 - lr: 1.0000e-04
# Epoch 93/100
# 51/51 [==============================] - 401s 8s/step - loss: 0.1020 - iou_score: 0.8909 - f1-score: 0.9116 - val_loss: 0.5911 - val_iou_score: 0.7494 - val_f1-score: 0.7738 - lr: 1.0000e-04
# Epoch 94/100
# 51/51 [==============================] - 401s 8s/step - loss: 0.1024 - iou_score: 0.8885 - f1-score: 0.9095 - val_loss: 0.5912 - val_iou_score: 0.7457 - val_f1-score: 0.7701 - lr: 1.0000e-04
# Epoch 95/100
# 51/51 [==============================] - 406s 8s/step - loss: 0.1026 - iou_score: 0.8866 - f1-score: 0.9075 - val_loss: 0.5904 - val_iou_score: 0.7456 - val_f1-score: 0.7700 - lr: 1.0000e-04
# Epoch 96/100
# 51/51 [==============================] - 406s 8s/step - loss: 0.1015 - iou_score: 0.8916 - f1-score: 0.9121 - val_loss: 0.5907 - val_iou_score: 0.7450 - val_f1-score: 0.7694 - lr: 1.0000e-04
# Epoch 97/100
# 51/51 [==============================] - 402s 8s/step - loss: 0.1017 - iou_score: 0.8895 - f1-score: 0.9101 - val_loss: 0.5904 - val_iou_score: 0.7477 - val_f1-score: 0.7719 - lr: 1.0000e-04
# Epoch 98/100
# 51/51 [==============================] - 394s 8s/step - loss: 0.1008 - iou_score: 0.8889 - f1-score: 0.9091 - val_loss: 0.5903 - val_iou_score: 0.7468 - val_f1-score: 0.7712 - lr: 1.0000e-05
# Epoch 99/100
# 51/51 [==============================] - 396s 8s/step - loss: 0.1011 - iou_score: 0.8885 - f1-score: 0.9089 - val_loss: 0.5903 - val_iou_score: 0.7469 - val_f1-score: 0.7713 - lr: 1.0000e-05
# Epoch 100/100
# 51/51 [==============================] - 393s 8s/step - loss: 0.1015 - iou_score: 0.8860 - f1-score: 0.9067 - val_loss: 0.5903 - val_iou_score: 0.7469 - val_f1-score: 0.7713 - lr: 1.0000e-05

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(os.path.join(result_dir,'UNET-Training.png'))
plt.show()

#Save model as Tensorflow frozen graph
#frozen_graph = freeze_session(K.get_session(),output_names=[out.op.name for out in model.outputs])
#tf.train.write_graph(frozen_graph, result_dir , "best_model.pb", as_text=False)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 3898084235310497015
# xla_global_id: -1
# ]
# 2022-06-28 09:37:59.083168: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [raw]
# Modèle entrainé sur le jeu validation de synthese testé sur le Jeu de Synthese

# %%
model.load_weights(os.path.join(result_dir,'best_model.h5'))

# %%
valid_imgs=[]
valid_labels=[]

for img,label in valid_dataset:
    valid_imgs.append(img)
    valid_labels.append(label)
    
valid_imgs = np.array(valid_imgs)
valid_labels = np.array(valid_labels)

# %%
predictions = model.predict(valid_imgs)
# Out:
# 6/6 [==============================] - 46s 7s/step

# %%
true_label = np.argmax(valid_labels,axis=3)
label_pred = np.argmax(predictions,axis=3)

# %%
i=random.choice(range(len(valid_imgs)-1))
print(i)

plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.imshow(label_pred[i])
plt.gca().set_title("Prédiction")

plt.subplot(132)
plt.imshow(true_label[i])
plt.gca().set_title("Label")

plt.subplot(133)
plt.imshow(valid_imgs[i])
plt.gca().set_title("images")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 105

# %% [markdown]
# ### Avec seuil

# %%
ious = []
threshold_iou = [0.01,0.05,0.1,0.15,0.2,
                 0.25,0.3,0.35,0.4,0.45,0.5,
                 0.55,0.6,0.65,0.7,0.75,0.8]

for threshold in threshold_iou:
    iou = []
    for idx_classe in range(1,11):
        prediction = np.where(predictions[...,idx_classe]<= threshold,0,1)
        target = valid_labels[...,idx_classe]

        intersection = np.logical_and(target,prediction)
        union = np.logical_or(target,prediction)
        iou_score = np.sum(intersection) / np.sum(union)

        # print("iou score for class", classes[idx_classe], ": with 0.5 threshold ",iou_score)
        iou.append(iou_score)
    ious.append(np.mean(iou))
    
plt.plot(threshold_iou,ious)
plt.gca().set_title("Finding best confidence threshold for class except background")
plt.show()

# %%
best_threshold = 0.5

# %%
conf_mat = np.zeros((11,11))

for idx_pred_class in range(11):
    for idx_target_class in range(11):
        prediction = np.where(predictions[...,idx_pred_class]<= best_threshold,0,1)
        target = valid_labels[...,idx_target_class]

        intersection = np.logical_and(target,prediction)
        conf_mat[idx_pred_class,idx_target_class] = np.sum(intersection)

# %%
(np.sum(conf_mat.flatten()) - len(valid_imgs)*SIZE[0]*SIZE[1]) /

# %% [markdown]
# ### Avec l'Argmax

# %%
prediction = np.zeros(predictions.shape)

for idx_class in range(11):
    prediction[...,idx_class][label_pred == idx_class] = 1

# %%
conf_mat = np.zeros((11,11))

for idx_pred_class in range(11):
    for idx_target_class in range(11):
        target = valid_labels[...,idx_target_class]

        intersection = np.logical_and(target,prediction[...,idx_pred_class])
        conf_mat[idx_pred_class,idx_target_class] = np.sum(intersection)

# %%
classe = list(classes.values())

# %%
data = conf_mat

fig = plt.figure(figsize=(25,25))
ax = fig.add_subplot(111)
cax = ax.matshow(data, interpolation='nearest')
fig.colorbar(cax)

for i in range(len(data)):
    for j in range(len(data)):
        c = data[j,i]
        ax.text(i, j, str(round(c,2)), va='center', ha='center',
                color="red",size = "large")
        
plt.xticks(range(11), classe, rotation='vertical')
plt.yticks(range(11), classe, rotation='horizontal')
plt.xlabel('Réalité', fontsize=20)
plt.gca().xaxis.set_label_position('top') 
plt.ylabel('Prediction', fontsize=20)
plt.gca().set_title("Matrice de confusion avec le nombre d'effectifs", fontsize=25)
plt.show()
plt.show()

# %%
conf_mat_norm = conf_mat.T/conf_mat.sum(axis=1)

conf_mat_norm = conf_mat_norm.T

data = conf_mat_norm

fig = plt.figure(figsize=(25,25))
ax = fig.add_subplot(111)
cax = ax.matshow(data, interpolation='nearest')
fig.colorbar(cax)

for i in range(len(data)):
    for j in range(len(data)):
        c = data[j,i]
        ax.text(i, j, str(round(c,2)), va='center', ha='center',
                color="red",size = "large")
        
plt.xticks(range(11), classe, rotation='vertical')
plt.yticks(range(11), classe, rotation='horizontal')
plt.xlabel('Réalité', fontsize=20)
plt.gca().xaxis.set_label_position('top') 
plt.ylabel('Prediction', fontsize=20)
plt.gca().set_title("Etudes des FP", fontsize=25)
plt.show()
plt.show()

# %%
conf_mat_norm_bis = conf_mat / conf_mat.sum(axis=0)

data = conf_mat_norm_bis

fig = plt.figure(figsize=(25,25))
ax = fig.add_subplot(111)
cax = ax.matshow(data, interpolation='nearest')
fig.colorbar(cax)

for i in range(len(data)):
    for j in range(len(data)):
        c = data[j,i]
        ax.text(i, j, str(round(c,2)), va='center', ha='center',
                color="red",size = "large")
        
plt.xticks(range(11), classe, rotation='vertical')
plt.yticks(range(11), classe, rotation='horizontal')
plt.xlabel('Réalité', fontsize=20)
plt.gca().xaxis.set_label_position('top') 
plt.ylabel('Prediction', fontsize=20)
plt.gca().set_title("Etudes des FN", fontsize=25)
plt.show()
plt.show()

# %%
for idx_classe in range(11):
        prediction = np.where(predictions[...,idx_classe]<= threshold,0,1)
        target = valid_labels[...,idx_classe]

        intersection = np.logical_and(target,prediction)
        union = np.logical_or(target,prediction)
        iou_score = np.sum(intersection) / np.sum(union)
        dice_score = 2*iou_score / (iou_score +1)
        
        print("dice score for class", classes[idx_classe], ": with 0.2 threshold ",dice_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
#       1 for idx_classe in range(11):
# ----> 2         prediction = np.where(predictions[...,idx_classe]<= threshold,0,1)
#       3         target = valid_labels[...,idx_classe]
#       5         intersection = np.logical_and(target,prediction)
#
# NameError: name 'threshold' is not defined

# %%
dico = {}
for key in classes:
    precision = conf_mat[key,key]/np.sum(conf_mat[key,:])
    recall = conf_mat[key,key]/np.sum(conf_mat[:,key])
    f1score = 2 * precision * recall /(precision + recall)
    dico[classes[key]] = {"precision":precision,"recall":recall,"f1":f1score}
    
dico
# Out:
# {'falaise': {'precision': 0.9591681200326211,
#   'recall': 0.9453137099884499,
#   'f1': 0.9521905221229148},
#  'batiment': {'precision': 0.9899926661646443,
#   'recall': 0.9965194500480534,
#   'f1': 0.9932453360705976},
#  'route': {'precision': 0.9887675582502986,
#   'recall': 0.9850244741846156,
#   'f1': 0.9868924670395061},
#  'pierrier': {'precision': 0.8171716340729598,
#   'recall': 0.7728298321662777,
#   'f1': 0.794382433250694},
#  'verger': {'precision': 0.9956354326767921,
#   'recall': 0.9945899020938743,
#   'f1': 0.995112392759596},
#  'champ': {'precision': 0.9910725429727424,
#   'recall': 0.9881752193341807,
#   'f1': 0.9896217605285387},
#  'prairie': {'precision': 0.9960849917809262,
#   'recall': 0.9951052147918699,
#   'f1': 0.9955948622338493},
#  'foret': {'precision': 0.9929049778847968,
#   'recall': 0.9935712948348974,
#   'f1': 0.993238024609638},
#  'foret_claire': {'precision': 0.9782043710956979,
#   'recall': 0.9851892217713191,
#   'f1': 0.9816843719916803},
#  'buisson': {'precision': 0.9838176831384157,
#   'recall': 0.9602080913771053,
#   'f1': 0.9718695216629102},
#  'eau': {'precision': 0.9956248121762803,
#   'recall': 0.9824945486262538,
#   'f1': 0.9890161026919769}}

# %%
sommef1,sommerecall,sommeprecision = 0,0,0
for key in dico:
    sommef1 += dico[key]["f1"]
    sommerecall += dico[key]["recall"]
    sommeprecision += dico[key]["precision"]
    
print("mean f1 score is:" ,sommef1/len(dico))
print("mean precision score is:" ,sommeprecision/len(dico))
print("mean recall score is:" ,sommerecall/len(dico))
# Out:
# mean f1 score is: 0.9675316177238091
# mean precision score is: 0.9716767991132884
# mean recall score is: 0.9635473599288088

# %% [markdown]
# ## Modèle entrainé sur le jeu de synthese testé sur le Jeu de validation Réelle

# %%
real_dir = "Real/Valid/"

x_valid_dir = os.path.join(real_dir, 'images')
y_valid_dir = os.path.join(real_dir, 'masks')

# Dataset for validation images
valid_dataset_real = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=12, 
    augmentation=False,
    preprocessing=get_preprocessing(preprocess_input),
    #preprocessing=False,
)

# %%
model.load_weights(os.path.join(result_dir,'best_model.h5'))

# %%
valid_imgs_real =[]
valid_labels_real =[]

for img,label in valid_dataset_real:
    valid_imgs_real.append(img)
    valid_labels_real.append(label)
    
valid_imgs_real = np.array(valid_imgs_real)
valid_labels_real = np.array(valid_labels_real)

# %%
predictions = model.predict(valid_imgs_real)
# Out:
# 2/2 [==============================] - 20s 9s/step

# %%
classes_real = {0:"background",1:"buisson",2:"champ",3:"eau",
         4:"falaise",5:"foret",6:"foret_claire",
         7:"pierrier",8:"prairie",9:"route",10:"verger",
         11:"batiment"}

classes_syn = {0: "falaise" , 1: "batiment", 2:"route",3:"pierrier",4:"verger",
            5:"champ",6:"prairie",7:"foret",8:"foret_claire",9:"buisson",10:"eau"}

correspondance = {1:9,2:5,3:10,4:0,5:7,6:8,7:3,8:6,9:2,10:4,11:1}

# %%
valid_labels_real.shape,predictions.shape
# Out:
# ((64, 512, 512, 12), (64, 512, 512, 11))

# %%
true_label = np.argmax(valid_labels_real,axis=3)
label_pred = np.argmax(predictions,axis=3)

# %%
i=random.choice(range(len(valid_imgs_real)-1))
#i = 48
print(i)

plt.figure(figsize=(15, 5))
plt.subplot(131)
plt.imshow(label_pred[i])
plt.gca().set_title("Prédiction")

plt.subplot(132)
plt.imshow(true_label[i])
plt.gca().set_title("Label")

plt.subplot(133)
plt.imshow(valid_imgs_real[i])
plt.gca().set_title("images")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 51

# %%
prediction = np.zeros(predictions.shape)

for idx_class in range(11):
    prediction[...,idx_class][label_pred == idx_class] = 1

# %%
iou = {}

a = list(classes_real.values())[1:]

for idx_classe in range(11):
    # doesn't take into account background class since it is not present
    # in the synthese dataset
    target = valid_labels_real[...,idx_classe]

    intersection = np.logical_and(target,prediction[...,correspondance[idx_classe]])
    union = np.logical_or(target,prediction[...,correspondance[idx_classe]])
    iou_score = np.sum(intersection) / np.sum(union)
    iou[a[idx_classe]] = iou_score
print(iou)
    
print("mIou: ", np.mean(list(iou.values())))

# %%
conf_mat = np.zeros((11,12))

for idx_pred_class in range(1,12):
    for idx_target_class in range(0,12):
        target = valid_labels_real[...,idx_target_class]
        
        intersection = np.logical_and(target,prediction[...,correspondance[idx_pred_class]])
        conf_mat[idx_pred_class-1,idx_target_class] = np.sum(intersection)

# %%
data = conf_mat

fig = plt.figure(figsize=(25,25))
ax = fig.add_subplot(111)
cax = ax.matshow(data, interpolation='nearest')
fig.colorbar(cax)

for i in range(len(data)+1):
    for j in range(len(data)):
        c = data[j,i]
        ax.text(i, j, str(round(c,2)), va='center', ha='center',
                color="red",size = "large")
        
plt.xticks(range(12), list(classes_real.values()), rotation='vertical')
plt.yticks(range(11), list(classes_real.values())[1:], rotation='horizontal')
plt.xlabel('Réalité', fontsize=20)
plt.gca().xaxis.set_label_position('top') 
plt.ylabel('Prediction', fontsize=20)
plt.gca().set_title("Matrice de Confusion réalisé avec les effectifs", fontsize=25)
plt.show()

# %%
assert np.sum(conf_mat.flatten())/len(label_pred.flatten()) == 1

# %%
conf_mat_norm = conf_mat[:,1:].T/conf_mat[:,1:].sum(axis=1)

conf_mat_norm = conf_mat_norm.T

data = conf_mat_norm

fig = plt.figure(figsize=(25,25))
ax = fig.add_subplot(111)
cax = ax.matshow(data, interpolation='nearest')
fig.colorbar(cax)

for i in range(len(data)):
    for j in range(len(data)):
        c = data[j,i]
        ax.text(i, j, str(round(c,2)), va='center', ha='center',
                color="red",size = "large")
        
plt.xticks(range(11), list(classes_real.values())[1:], rotation='vertical')
plt.yticks(range(11), list(classes_real.values())[1:], rotation='horizontal')
plt.xlabel('Réalité', fontsize=20)
plt.gca().xaxis.set_label_position('top') 
plt.ylabel('Prediction', fontsize=20)
plt.gca().set_title("Etudes des FP", fontsize=25)
plt.show()

# %%
conf_mat_norm_bis = conf_mat[:,1:] / conf_mat[:,1:].sum(axis=0)

data = conf_mat_norm_bis

fig = plt.figure(figsize=(25,25))
ax = fig.add_subplot(111)
cax = ax.matshow(data, interpolation='nearest')
fig.colorbar(cax)

for i in range(11):
    for j in range(11):
        c = data[j,i]
        ax.text(i, j, str(round(c,2)), va='center', ha='center',
                color="red",size = "large")
        
plt.xticks(range(11), list(classes_real.values())[1:], rotation='vertical')
plt.yticks(range(11), list(classes_real.values())[1:], rotation='horizontal')
plt.xlabel('Réalité', fontsize=20)
plt.gca().xaxis.set_label_position('top') 
plt.ylabel('Prediction', fontsize=20)
plt.gca().set_title("Etudes des FN", fontsize=25)
plt.show()

# %%
conf_mat_without_background = conf_mat[:,1:]
conf_mat_without_background.shape
# Out:
# (11, 11)

# %%
dico = {}
for key in range(11):
    precision = conf_mat_without_background[key,key]/np.sum(conf_mat_without_background[key,:])
    recall = conf_mat_without_background[key,key]/np.sum(conf_mat_without_background[:,key])
    f1score = 2 * precision * recall /(precision + recall)
    dico[classes_real[key+1]] = {"precision":precision,"recall":recall,"f1":f1score}
    
dico
# Out:
# {'buisson': {'precision': 0.8177306776891569,
#   'recall': 0.512076592155997,
#   'f1': 0.6297765822580239},
#  'champ': {'precision': 0.8875659294308147,
#   'recall': 0.6690928643764363,
#   'f1': 0.7629983300236716},
#  'eau': {'precision': 0.993236277390097,
#   'recall': 0.8257322978981657,
#   'f1': 0.9017717896035352},
#  'falaise': {'precision': 0.4006687928868271,
#   'recall': 0.6068588760202827,
#   'f1': 0.48266548068392706},
#  'foret': {'precision': 0.8674006817489451,
#   'recall': 0.701974558825491,
#   'f1': 0.7759689271926752},
#  'foret_claire': {'precision': 0.4864560987678944,
#   'recall': 0.83589102955672,
#   'f1': 0.6150038526546733},
#  'pierrier': {'precision': 0.8915927682683715,
#   'recall': 0.20954391482532622,
#   'f1': 0.3393363275629006},
#  'prairie': {'precision': 0.6676719070496373,
#   'recall': 0.8034324906628457,
#   'f1': 0.7292878793111236},
#  'route': {'precision': 0.9378224104120608,
#   'recall': 0.233011305624261,
#   'f1': 0.3732779835442094},
#  'verger': {'precision': 0.9183900375449001,
#   'recall': 0.8876331897910354,
#   'f1': 0.9027497167916054},
#  'batiment': {'precision': 0.3414294908621263,
#   'recall': 0.8435949156341049,
#   'f1': 0.48611350274285997}}

# %%
sommef1,sommerecall,sommeprecision = 0,0,0
for key in dico:
    sommef1 += dico[key]["f1"]
    sommerecall += dico[key]["recall"]
    sommeprecision += dico[key]["precision"]
    
print("mean f1 score is:" ,sommef1/len(dico))
print("mean precision score is:" ,sommeprecision/len(dico))
print("mean recall score is:" ,sommerecall/len(dico))
# Out:
# mean f1 score is: 0.6362682156699279
# mean precision score is: 0.7463604610955301
# mean recall score is: 0.6480765486700606
